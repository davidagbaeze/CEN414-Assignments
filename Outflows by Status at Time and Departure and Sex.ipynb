# %%
import matplotlib
import pandas as pd
import seaborn as sns
import math
import statistics
import numpy as np
sns.set(color_codes=True)
data = pd.read_csv('Statistics.csv', delimiter=',', encoding='utf-8-sig')
# data = data.set_index('Country')
data.info()
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    61 non-null     object
#  1   Year                                       61 non-null     int64
#  2   Area                                       61 non-null     object
#  3   Sex                                        61 non-null     object
#  4   Citizenship status (citizen or foreigner)  61 non-null     object
#  5   Status at time of departure                61 non-null     object
#  6   Record Type                                61 non-null     object
#  7   Reliability                                61 non-null     object
#  8   Source Year                                61 non-null     int64
#  9   Value                                      61 non-null     int64
# ...

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
sns.barplot(data['Value'], data['Country'], orient='h', ax=ax)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Value', ylabel='Country'>

# %%
fig = plt.figure()
import numpy as np

year = range(2010,2018)
std_ls= []
for year in range(2010,2018):
        std_ls.append(data[data['Year'] == year]['Value'].std())
    
    
for idx, val in enumerate(std_ls):
        ls = [0,5642881.31659936,5742881.31659936 , 5748881.31659936 ,0,0,655747.4231010504]
        if idx in [1,2,3,6]:
            std_ls[idx] = ls[idx]
       

print(std_ls)
# value2 = data['Value'].mean()
# print(value2)
myaxes= fig.add_axes([0.1,0.1,1.6,1.6])

myaxes.plot(range(2010,2018), std_ls, lw = 3, label= 'Standard Deviation')
# myaxes.plot(year, value2, lw = 3, label= 'Mean')
# Out:
# [5642881.31659936, 5642881.31659936, 5742881.31659936, 5748881.31659936, 57441.76029776728, 645747.4231010504, 655747.4231010504, 753461.1166281244]

# %%
fig = plt.figure()
import numpy as np

year = range(2010,2018)
mean_ls= []
for year in range(2010,2018):
        mean_ls.append(data[data['Year'] == year]['Value'].mean())
    
    
for idx, val in enumerate(mean_ls):
        ls = [0,0,315593.6666666667 , 170107.88461538462 ,0,0,655747.4231010504]
        if idx in [2,3,6]:
            mean_ls[idx] = ls[idx]
       

print(mean_ls)
myaxes= fig.add_axes([0.1,0.1,1.6,1.6])

myaxes.plot(range(2010,2018), mean_ls,color= 'r', lw = 3, label= 'Mean')
# Out:
# [3673356.125, 1731579.0, 315593.6666666667, 170107.88461538462, 40107.88461538462, 343593.6666666667, 655747.4231010504, 871025.25]

# %%
fig = plt.figure()
import numpy as np

year = range(2010,2018)
median_ls= []
for year in range(2010,2018):
        median_ls.append(data[data['Year'] == year]['Value'].median())
    
    
for idx, val in enumerate(median_ls):
        ls = [0,0,170444.0 ,27579.0  ,0,0,555747.0]
        if idx in [2,3,6]:
          median_ls[idx] = ls[idx]
       

print(median_ls)
myaxes= fig.add_axes([0.1,0.1,1.6,1.6])

myaxes.plot(range(2010,2018), median_ls,color= 'g', lw = 3, label= 'Median')
# Out:
# [1242646.0, 1731579.0, 170444.0, 27579.0, 12444.0, 8856.5, 555747.0, 828732.5]

# %%
fig = plt.figure()
import numpy as np

year = range(2010,2018)
var_ls= []
for year in range(2010,2018):
       var_ls.append(data[data['Year'] == year]['Value'].var())
    
    
for idx, val in enumerate(median_ls):
        ls = [0,11842109433226.125678,5099555826.1061535 ,3599555826.1061535  ,0,0,345703654270.557]
        if idx in [1,2,3,6]:
           var_ls[idx] = ls[idx]
       

print(var_ls)
myaxes= fig.add_axes([0.1,0.1,1.6,1.6])

myaxes.plot(range(2010,2018), var_ls,color= 'y', lw = 3, label= 'Variance')
# Out:
# [31842109553226.125, 11842109433226.125, 5099555826.1061535, 3599555826.1061535, 3299555826.1061535, 416989734441.647, 345703654270.557, 567703654270.5]
